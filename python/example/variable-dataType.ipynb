# %% [markdown]
# # Chapter 1. 변수와 자료형

# %% [markdown]
# ##1. 기본 예제

# %% [markdown]
# 문제 1) 아래 각 변수의 선언에서, 변수 선언 가능 여부를 맞혀 보자

# %%
name = "variable' # 에러

# %%
number = 41 # 정상 동작

# %%
int = 3 # 정상 동작

# %%
"name" = "variable" # 에러

# %%
is_book = true # 에러

# %%
for = "repeat" # 에러

# %%
data_type = ["", 1, 2] # 정상 동작

# %%
4things = [3.141, 2.718, 41, 1729] # 에러

# %% [markdown]
# 문제 2) 아래 코드에서 각 문자열 변수의 대입 값을 맞혀 보자

# %%
string = "ABCDE"

# %%
str1 = string[1]
print(str1)
# Out:
# B

# %%
str2 = string[-1]
print(str2)
# Out:
# E

# %%
str3 = string[1:3]
print(str3)
# Out:
# BC

# %%
str4 = string[:3]
print(str4)
# Out:
# ABC

# %%
str5 = string[-2]
print(str5)
# Out:
# D

# %%
str6 = string[1:-2]
print(str6)
# Out:
# BC

# %% [markdown]
# 문제 3) 아래 코드에서 각 리스트 변수의 대입 값을 맞혀 보자

# %%
num = [1, 20, 300, 4000]

# %%
n1 = num[1] # 20

# %%
n2 = num[-1] # 4000

# %%
n3 = num[1:3] # 20, 300

# %%
n4 = num[:3] # 1, 20, 300

# %%
n5 = num[-2:] # 300, 4000

# %%
n6 = num[1:2] # 20

# %% [markdown]
# 문제 4) 아래 코드에서 각 문자열 변수의 대입 값을 맞혀 보자

# %%
string = "ABCDE"

# %%
str1 = string + string # ABCDEABCDE

# %%
str2 = string + "xyz" #ABCDExyz

# %%
str3 = "xyz" + string #xyzABCDE

# %%
str4 = "string" + 'string' #stringstring

# %%
str5 = string + "" #ABCDE

# %%
str6 = string * 2 #ABCDEABCDE

# %%
str7 = string * 0 # 에러

# %%
str8 = string * -1 # 에러

# %% [markdown]
# 문제 5) 아래 코드에서 각 리스트 변수의 대입 값을 맞혀 보자

# %%
num = [1, 20, 300, 4000]

# %%
n1 = num + num # 1, 20, 300, 4000, 1, 20, 300, 4000

# %%
n2 = num + [9] # 1, 20, 300, 4000, 9

# %%
n3 = num + [num] # 1, 20, 300, 4000, 4

# %%
n4 = num * 2 # 1, 20, 300, 4000, 1, 20, 300, 4000

# %%
n5 = num * 0 # list 내용 없음

# %%
n6 = num * -1 # 에러

# %% [markdown]
# 문제 6) 아래 코드를 에러가 발생하지 않게 고쳐 보자

# %%
# name = "variable'
name = "variable"

# %%
# "name" = "variable"
name = "variable"

# %%
# is_book = true
is_book = True

# %%
# True = 1
true = 1

# %%
# 4things = [3.141, 2.718, 41, 1729]
things_4 = [3.141, 2.718, 41, 1729]

# %%
# for = "repeat"
For = "repeat"

# %% [markdown]
# ##2. 심화 예제

# %% [markdown]
# 문제 7) 아래 코드에서 변수의 대입 값을 맞혀 보자

# %%
string = "10"

# %%
int1 = int(string+string) # 1010

# %%
int2 = int(string) + int(string) # 20

# %%
int3 = int(string) * 3 # 30

# %%
int4 = int(string*3) # 101010

# %%
int5 = int(string[0]) # 1

# %% [markdown]
# 문제 8) 아래 코드에서 변수의 대입 값을 맞혀 보자

# %%
string = "Hello_Python"

# %%
str1 = string[:5] + string[:5] # HelloHello

# %%
str2 = string[0] + string[6] # HP

# %%
str3 = string[-6:] # Python

# %%
str4 = string[:2] + string[2:] # Hello_Python

# %%
str5 = string[:4] + string[4:] # Hello_Python

# %% [markdown]
# 문제 9) 아래 코드에서 각 변수의 대입 값을 맞혀 보자

# %%
num = [1, 20, 300, 4000]

# %%
n1 = num[0] + num[1] # 21

# %%
n2 = num[0:1] + num[1:2] # 1, 20

# %%
n3 = num[1:][0] # 20, 300, 4000, 1

# %%
n4 = num[2] * 2 # 90000

# %%
n5 = num[2:3] * 2 # 300300
