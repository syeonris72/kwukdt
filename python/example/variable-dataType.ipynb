# %% [markdown]
# # Chapter 1. 변수와 자료형

# %% [markdown]
# ##1. 기본 예제

# %% [markdown]
# 문제 1) 아래 각 변수의 선언에서, 변수 선언 가능 여부를 맞혀 보자

# %%
name = "variable' # 에러

# %%
number = 41 # 정상 동작

# %%
int = 3 # 정상 동작

# %%
"name" = "variable" # 에러

# %%
is_book = true # 에러

# %%
for = "repeat" # 에러

# %%
data_type = ["", 1, 2] # 정상 동작

# %%
4things = [3.141, 2.718, 41, 1729] # 에러

# %% [markdown]
# 문제 2) 아래 코드에서 각 문자열 변수의 대입 값을 맞혀 보자

# %%
string = "ABCDE"

# %%
str1 = string[1]
print(str1)
# Out:
# B

# %%
str2 = string[-1]
print(str2)
# Out:
# E

# %%
str3 = string[1:3]
print(str3)
# Out:
# BC

# %%
str4 = string[:3]
print(str4)
# Out:
# ABC

# %%
str5 = string[-2]
print(str5)
# Out:
# D

# %%
str6 = string[1:-2]
print(str6)
# Out:
# BC
